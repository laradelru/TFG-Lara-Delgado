# %%
import numpy as np
import scipy as sc
import matplotlib.pyplot as plt

# %%
from numpy.core.fromnumeric import resize
func = lambda th: (th[0]-4)**2+4*(th[1]-2)**2

#Representamos la función
_x =np.linspace(-16,16, 100)
_y =np.linspace(-16,16, 100)
_z=np.zeros((100,100))

for ix, x in enumerate(_x):
  for iy, y in enumerate(_y):
    _z[iy,ix]=func([x,y])

plt.contour(_x,_y,_z,100)
plt.colorbar()

#Algoritmo Adagrad
min=[4,2]
Theta = [0,0]
Thetaold=[0,0]
lr=0.1
E=10**(-8)
plt.plot(Theta[0],Theta[1], "o", c = "white")
grad=np.zeros(2)
Gk = [0,0]
contador= 0
diferencia=1


for _ in range(100000):

  if diferencia < 10**-3:
    break
  else:

    grad[0] = 2*Theta[0]-8
    grad[1]= 8*Theta[1]-16
    #print(grad)

    for it, th in enumerate(Theta): 
      Gk[it]= Gk[it]+ grad[it]**2

    for it, th in enumerate(Theta): 

      Thetaold[it]=Theta[it]
      Theta[it] = Theta[it] - lr * grad[it]/ np.sqrt(Gk[it] + E)
    diferencia=np.sqrt((min[0]-Theta[0])**2+(min[1]-Theta[1])**2)
    #print(diferencia)
    contador=contador+1
  
    plt.plot(Theta[0],Theta[1], ".", c = "red")
  #print(Theta)
plt.plot(Theta[0],Theta[1], "o", c = "green")
print(Theta)
print(contador)


plt.show()
# Out:
# [3.9990021481936155, 1.9999999999998137]
# 3347

# %%
from numpy.core.fromnumeric import resize
func = lambda th: (th[0]-4)**2+4*(th[1]-2)**2

#Representamos la función
_x =np.linspace(-16,16, 100)
_y =np.linspace(-16,16, 100)
_z=np.zeros((100,100))

for ix, x in enumerate(_x):
  for iy, y in enumerate(_y):
    _z[iy,ix]=func([x,y])

plt.contour(_x,_y,_z,100)
plt.colorbar()

#Algoritmo Adagrad
min=[4,2]
Theta = [3.5,1]
Thetaold=[0,0]
lr=0.1
E=10**(-8)
plt.plot(Theta[0],Theta[1], "o", c = "white")
grad=np.zeros(2)
Gk = [0,0]
contador= 0
diferencia=1


for _ in range(100000):

  if diferencia < 10**-3:
    break
  else:

    grad[0] = 2*Theta[0]-8
    grad[1]= 8*Theta[1]-16
    #print(grad)

    for it, th in enumerate(Theta): 
      Gk[it]= Gk[it]+ grad[it]**2

    for it, th in enumerate(Theta): 

      Thetaold[it]=Theta[it]
      Theta[it] = Theta[it] - lr * grad[it]/ np.sqrt(Gk[it] + E)
    diferencia=np.sqrt((min[0]-Theta[0])**2+(min[1]-Theta[1])**2)
    #print(diferencia)
    contador=contador+1
  
    plt.plot(Theta[0],Theta[1], ".", c = "red")
  #print(Theta)
plt.plot(Theta[0],Theta[1], "o", c = "green")
print(Theta)
print(contador)


plt.show()
# Out:
# [3.999999999945393, 1.9990250021382636]
# 204
