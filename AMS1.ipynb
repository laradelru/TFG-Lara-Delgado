# %%
import numpy as np
import scipy as sc
import matplotlib.pyplot as plt

# %%
#300 IETRACCIONES

from numpy.core.fromnumeric import resize
func = lambda th: (th[0]-4)**2+4*(th[1]-2)**2

#Representamos la funcion
_x =np.linspace(-16,16, 100)
_y =np.linspace(-16,16, 100)
_z=np.zeros((100,100))
for ix, x in enumerate(_x):
  for iy, y in enumerate(_y):
    _z[iy,ix]=func([x,y])

plt.contourf(_x,_y,_z,100)
plt.colorbar()

#Algoritmo AMSGrad
Theta = [0,0]
lr=0.01
b1= 0.9
b2=0.999
k=1
E=10**(-8)
plt.plot(Theta[0],Theta[1], "o", c = "white")
grad=np.zeros(2)
m=[0,0]
v=[0,0]
V=np.zeros(2)
iteraciones=300

for _ in range(iteraciones):

  grad[0] = 2*Theta[0]-8
  grad[1]= 8*Theta[1]-16
  #print(grad)
  for it, th in enumerate(Theta):
      m[it]= b1*m[it] + (1-b1)* grad[it]
      v[it]= b2*v[it] + (1-b2)* grad[it]**2
 
  b1k= b1**(k)
  b2k= b2**(k)
  k=k+1

  for it, th in enumerate(Theta):

    if V[1] < v[1]:
      V[it]= v[it]
    else:
      V[it]=V[it]
  #print(V)

  for it, th in enumerate(Theta):  
    Theta[it] = Theta[it] - lr * m[it]/ np.sqrt(V[it] + E)
    plt.plot(Theta[0],Theta[1], ".", c = "red")
print(Theta)
plt.plot(Theta[0],Theta[1], "o", c = "green")

plt.show()
min=[4,2]
Error=np.zeros(2)
for it, th in enumerate(Theta):
  Error[it]=min[it]-Theta[it]
print(Error)

print(np.sqrt(Error[0]**2+Error[1]**2))
# Out:
# [3.9930566060825328, 1.9999996627810295]
# [6.94339392e-03 3.37218971e-07]
# 0.00694339392565607

# %%
#100 IETRACCIONES

from numpy.core.fromnumeric import resize
func = lambda th: (th[0]-4)**2+4*(th[1]-2)**2

#Representamos la funcion
_x =np.linspace(-16,16, 100)
_y =np.linspace(-16,16, 100)
_z=np.zeros((100,100))
for ix, x in enumerate(_x):
  for iy, y in enumerate(_y):
    _z[iy,ix]=func([x,y])

plt.contourf(_x,_y,_z,100)
plt.colorbar()

#Algoritmo AMSGrad
Theta = [0,0]
lr=0.01
b1= 0.9
b2=0.999
k=1
E=10**(-8)
plt.plot(Theta[0],Theta[1], "o", c = "white")
grad=np.zeros(2)
m=[0,0]
v=[0,0]
V=np.zeros(2)
iteraciones=100

for _ in range(iteraciones):

  grad[0] = 2*Theta[0]-8
  grad[1]= 8*Theta[1]-16
  #print(grad)
  for it, th in enumerate(Theta):
      m[it]= b1*m[it] + (1-b1)* grad[it]
      v[it]= b2*v[it] + (1-b2)* grad[it]**2
 
  b1k= b1**(k)
  b2k= b2**(k)
  k=k+1

  for it, th in enumerate(Theta):

    if V[1] < v[1]:
      V[it]= v[it]
    else:
      V[it]=V[it]
  #print(V)

  for it, th in enumerate(Theta):  
    Theta[it] = Theta[it] - lr * m[it]/ np.sqrt(V[it] + E)
    plt.plot(Theta[0],Theta[1], ".", c = "red")
print(Theta)
plt.plot(Theta[0],Theta[1], "o", c = "green")

plt.show()
min=[4,2]
Error=np.zeros(2)
for it, th in enumerate(Theta):
  Error[it]=min[it]-Theta[it]
print(Error)
print(np.sqrt(Error[0]**2+Error[1]**2))
# Out:
# [3.4792393702344993, 2.0111750735871365]
# [ 0.52076063 -0.01117507]
# 0.5208805196812787

# %%
#50 IETRACCIONES

from numpy.core.fromnumeric import resize
func = lambda th: (th[0]-4)**2+4*(th[1]-2)**2

#Representamos la funcion
_x =np.linspace(-16,16, 100)
_y =np.linspace(-16,16, 100)
_z=np.zeros((100,100))
for ix, x in enumerate(_x):
  for iy, y in enumerate(_y):
    _z[iy,ix]=func([x,y])

plt.contourf(_x,_y,_z,100)
plt.colorbar()

#Algoritmo AMSGrad
Theta = [0,0]
lr=0.01
b1= 0.9
b2=0.999
k=1
E=10**(-8)
plt.plot(Theta[0],Theta[1], "o", c = "white")
grad=np.zeros(2)
m=[0,0]
v=[0,0]
V=np.zeros(2)
iteraciones=50

for _ in range(iteraciones):

  grad[0] = 2*Theta[0]-8
  grad[1]= 8*Theta[1]-16
  #print(grad)
  for it, th in enumerate(Theta):
      m[it]= b1*m[it] + (1-b1)* grad[it]
      v[it]= b2*v[it] + (1-b2)* grad[it]**2
 
  b1k= b1**(k)
  b2k= b2**(k)
  k=k+1

  for it, th in enumerate(Theta):

    if V[1] < v[1]:
      V[it]= v[it]
    else:
      V[it]=V[it]
  #print(V)

  for it, th in enumerate(Theta):  
    Theta[it] = Theta[it] - lr * m[it]/ np.sqrt(V[it] + E)
    plt.plot(Theta[0],Theta[1], ".", c = "red")
print(Theta)
plt.plot(Theta[0],Theta[1], "o", c = "green")

plt.show()
min=[4,2]
Error=np.zeros(2)
for it, th in enumerate(Theta):
  Error[it]=min[it]-Theta[it]
print(Error)
print(np.sqrt(Error[0]**2+Error[1]**2))
# Out:
# [2.479462524137805, 1.9783117989128942]
# [1.52053748 0.0216882 ]
# 1.5206921429295839

# %%
#10 IETRACCIONES

from numpy.core.fromnumeric import resize
func = lambda th: (th[0]-4)**2+4*(th[1]-2)**2

#Representamos la funcion
_x =np.linspace(-16,16, 100)
_y =np.linspace(-16,16, 100)
_z=np.zeros((100,100))
for ix, x in enumerate(_x):
  for iy, y in enumerate(_y):
    _z[iy,ix]=func([x,y])

plt.contourf(_x,_y,_z,100)
plt.colorbar()

#Algoritmo AMSGrad
Theta = [0,0]
lr=0.01
b1= 0.9
b2=0.999
k=1
E=10**(-8)
plt.plot(Theta[0],Theta[1], "o", c = "white")
grad=np.zeros(2)
m=[0,0]
v=[0,0]
V=np.zeros(2)
iteraciones=10

for _ in range(iteraciones):

  grad[0] = 2*Theta[0]-8
  grad[1]= 8*Theta[1]-16
  #print(grad)
  for it, th in enumerate(Theta):
      m[it]= b1*m[it] + (1-b1)* grad[it]
      v[it]= b2*v[it] + (1-b2)* grad[it]**2
 
  b1k= b1**(k)
  b2k= b2**(k)
  k=k+1

  for it, th in enumerate(Theta):

    if V[1] < v[1]:
      V[it]= v[it]
    else:
      V[it]=V[it]
  #print(V)

  for it, th in enumerate(Theta):  
    Theta[it] = Theta[it] - lr * m[it]/ np.sqrt(V[it] + E)
    plt.plot(Theta[0],Theta[1], ".", c = "red")
print(Theta)
plt.plot(Theta[0],Theta[1], "o", c = "green")

plt.show()
min=[4,2]
Error=np.zeros(2)
for it, th in enumerate(Theta):
  Error[it]=min[it]-Theta[it]
print(Error)
print(np.sqrt(Error[0]**2+Error[1]**2))
# Out:
# [0.5498791609765687, 0.5463203241894165]
# [3.45012084 1.45367968]
# 3.743864100595601
