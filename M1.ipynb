# %%
import numpy as np
import scipy as sc
import matplotlib.pyplot as plt

# %%
#300 ITERACIONES
from numpy.core.fromnumeric import resize
func = lambda th: (th[0]-4)**2+4*(th[1]-2)**2


#Representamos la funcion

_x =np.linspace(-16,16, 100)
_y =np.linspace(-16,16, 100)
_z=np.zeros((100,100))
for ix, x in enumerate(_x):
  for iy, y in enumerate(_y):
    _z[iy,ix]=func([x,y])

plt.contourf(_x,_y,_z,100)
plt.colorbar()

#Algoritmo Momentum

Theta = [0,0]
lr=0.01
li= 0.9
plt.plot(Theta[0],Theta[1], "o", c = "white")
grad=np.zeros(2)
vmo=np.zeros(2)

for _ in range(300):

  grad[0] = 2*Theta[0]-8
  grad[1]= 8*Theta[1]-16
  #print(grad)

  for it, th in enumerate(Theta):
    vmo[it]= li*vmo[it] - lr* grad[it]
    Theta[it] = Theta[it] + vmo[it]
  plt.plot(Theta[0],Theta[1], ".", c = "red")
  #print(Theta)

plt.plot(Theta[0],Theta[1], "o", c = "green")
print(Theta)
plt.show()

min=[4,2]
Error=np.zeros(2)
for it, th in enumerate(Theta):
  Error[it]=abs(min[it]-Theta[it])
print(Error)
print(np.sqrt(Error[0]**2+Error[1]**2))
# Out:
# [4.000000497106947, 2.0000001229935656]
# [4.97106947e-07 1.22993566e-07]
# 5.12096410495665e-07

# %%
#100 ITERACIONES
from numpy.core.fromnumeric import resize
func = lambda th: (th[0]-4)**2+4*(th[1]-2)**2


#Representamos la funcion

_x =np.linspace(-16,16, 100)
_y =np.linspace(-16,16, 100)
_z=np.zeros((100,100))
for ix, x in enumerate(_x):
  for iy, y in enumerate(_y):
    _z[iy,ix]=func([x,y])

plt.contourf(_x,_y,_z,100)
plt.colorbar()

#Algoritmo Momentum

Theta = [0,0]
lr=0.01
li= 0.9
plt.plot(Theta[0],Theta[1], "o", c = "white")
grad=np.zeros(2)
vmo=np.zeros(2)

for _ in range(100):

  grad[0] = 2*Theta[0]-8
  grad[1]= 8*Theta[1]-16
  #print(grad)

  for it, th in enumerate(Theta):
    vmo[it]= li*vmo[it] - lr* grad[it]
    Theta[it] = Theta[it] + vmo[it]
  plt.plot(Theta[0],Theta[1], ".", c = "red")
  #print(Theta)

plt.plot(Theta[0],Theta[1], "o", c = "green")
print(Theta)
plt.show()

min=[4,2]
Error=np.zeros(2)
for it, th in enumerate(Theta):
  Error[it]=min[it]-Theta[it]
print(Error)
print(np.sqrt(Error[0]**2+Error[1]**2))
# Out:
# [3.9830875451274856, 2.009711937915353]
# [ 0.01691245 -0.00971194]
# 0.01950263745975168

# %%
#50 ITERACIONES
from numpy.core.fromnumeric import resize
func = lambda th: (th[0]-4)**2+4*(th[1]-2)**2


#Representamos la funcion

_x =np.linspace(-16,16, 100)
_y =np.linspace(-16,16, 100)
_z=np.zeros((100,100))
for ix, x in enumerate(_x):
  for iy, y in enumerate(_y):
    _z[iy,ix]=func([x,y])

plt.contourf(_x,_y,_z,100)
plt.colorbar()

#Algoritmo Momentum

Theta = [0,0]
lr=0.01
li= 0.9
plt.plot(Theta[0],Theta[1], "o", c = "white")
grad=np.zeros(2)
vmo=np.zeros(2)

for _ in range(50):

  grad[0] = 2*Theta[0]-8
  grad[1]= 8*Theta[1]-16
  #print(grad)

  for it, th in enumerate(Theta):
    vmo[it]= li*vmo[it] - lr* grad[it]
    Theta[it] = Theta[it] + vmo[it]
  plt.plot(Theta[0],Theta[1], ".", c = "red")
  #print(Theta)

plt.plot(Theta[0],Theta[1], "o", c = "green")
print(Theta)
plt.show()
min=[4,2]

Error=np.zeros(2)
for it, th in enumerate(Theta):
  Error[it]=min[it]-Theta[it]
print(Error)
print(np.sqrt(Error[0]**2+Error[1]**2))
# Out:
# [3.704249527481376, 2.0219174423882533]
# [ 0.29575047 -0.02191744]
# 0.2965614881872424

# %%
#10 ITERACIONES

from numpy.core.fromnumeric import resize
func = lambda th: (th[0]-4)**2+4*(th[1]-2)**2


#Representamos la funcion

_x =np.linspace(-16,16, 100)
_y =np.linspace(-16,16, 100)
_z=np.zeros((100,100))
for ix, x in enumerate(_x):
  for iy, y in enumerate(_y):
    _z[iy,ix]=func([x,y])

plt.contourf(_x,_y,_z,100)
plt.colorbar()

#Algoritmo Momentum

Theta = [0,0]
lr=0.01
li= 0.9
plt.plot(Theta[0],Theta[1], "o", c = "white")
grad=np.zeros(2)
vmo=np.zeros(2)

for _ in range(10):

  grad[0] = 2*Theta[0]-8
  grad[1]= 8*Theta[1]-16
  #print(grad)

  for it, th in enumerate(Theta):
    vmo[it]= li*vmo[it] - lr* grad[it]
    Theta[it] = Theta[it] + vmo[it]
  plt.plot(Theta[0],Theta[1], ".", c = "red")
  #print(Theta)

plt.plot(Theta[0],Theta[1], "o", c = "green")
print(Theta)
plt.show()
min=[4,2]
Error=np.zeros(2)
for it, th in enumerate(Theta):
  Error[it]=min[it]-Theta[it]
print(Error)
print(np.sqrt(Error[0]**2+Error[1]**2))
# Out:
# [2.7715209555953875, 3.1242539610262705]
# [ 1.22847904 -1.12425396]
# 1.665265063413188
