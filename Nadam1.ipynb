# %%
import numpy as np
import scipy as sc
import matplotlib.pyplot as plt
from numpy.lib.function_base import gradient

# %%
#300 IETRACIONES
from numpy.core.fromnumeric import resize
func = lambda th: (th[0]-4)**2+4*(th[1]-2)**2

#Representamos la funcion
_x =np.linspace(-16,16, 100)
_y =np.linspace(-16,16, 100)
_z=np.zeros((100,100))
for ix, x in enumerate(_x):
  for iy, y in enumerate(_y):
    _z[iy,ix]=func([x,y])

plt.contourf(_x,_y,_z,100)
plt.colorbar()

#Algoritmo Nadam
Theta = [0,0]
lr=0.01
b1= 0.9
b2=0.999
k=1
E=10**(-8)
plt.plot(Theta[0],Theta[1], "o", c = "white")
grad=np.zeros(2)
m=[0,0]
v=[0,0]
M=np.zeros(2)
V=np.zeros(2)
iteraciones=300

for _ in range(iteraciones):

  grad[0] = 2*Theta[0]-8
  grad[1]= 8*Theta[1]-16

  for it, th in enumerate(Theta):
      m[it]= b1*m[it] + (1-b1)* grad[it]
      v[it]= b2*v[it] + (1-b2)* grad[it]**2
  
  b1k= b1**(k)
  b2k= b2**(k)
  k=k+1

  for it, th in enumerate(Theta):
    M[it]= m[it]/(1-b1k)
    V[it]= v[it]/(1-b2k)
  
  for it, th in enumerate(Theta):  

    Theta[it] = Theta[it] - (lr/ np.sqrt(V[it] + E)) * (b1*M[it] + (1-b1)*grad[it]/(1-b1k))
    #print(Theta)
    plt.plot(Theta[0],Theta[1], ".", c = "red")
print(Theta)
plt.plot(Theta[0],Theta[1], "o", c = "green")

plt.show()

min=[4,2]
Error=np.zeros(2)
for it, th in enumerate(Theta):
  Error[it]=min[it]-Theta[it]
print(Error)
print(np.sqrt(Error[0]**2+Error[1]**2))
# Out:
# [2.4609915331530976, 1.8270595220207302]
# [1.53900847 0.17294048]
# 1.5486947633249593

# %%
#100 IETRACIONES
from numpy.core.fromnumeric import resize
func = lambda th: (th[0]-4)**2+4*(th[1]-2)**2

#Representamos la funcion
_x =np.linspace(-16,16, 100)
_y =np.linspace(-16,16, 100)
_z=np.zeros((100,100))
for ix, x in enumerate(_x):
  for iy, y in enumerate(_y):
    _z[iy,ix]=func([x,y])

plt.contourf(_x,_y,_z,100)
plt.colorbar()

#Algoritmo AdaMax
Theta = [0,0]
lr=0.01
b1= 0.9
b2=0.999
k=1
E=10**(-8)
plt.plot(Theta[0],Theta[1], "o", c = "white")
grad=np.zeros(2)
m=[0,0]
v=[0,0]
M=np.zeros(2)
V=np.zeros(2)
iteraciones=100

for _ in range(iteraciones):

  grad[0] = 2*Theta[0]-8
  grad[1]= 8*Theta[1]-16

  for it, th in enumerate(Theta):
      m[it]= b1*m[it] + (1-b1)* grad[it]
      v[it]= b2*v[it] + (1-b2)* grad[it]**2
  
  b1k= b1**(k)
  b2k= b2**(k)
  k=k+1

  for it, th in enumerate(Theta):
    M[it]= m[it]/(1-b1k)
    V[it]= v[it]/(1-b2k)
  
  for it, th in enumerate(Theta):  

    Theta[it] = Theta[it] - (lr/ np.sqrt(V[it] + E)) * (b1*M[it] + (1-b1)*grad[it]/(1-b1k))
    #print(Theta)
    plt.plot(Theta[0],Theta[1], ".", c = "red")
print(Theta)
plt.plot(Theta[0],Theta[1], "o", c = "green")

plt.show()

min=[4,2]
Error=np.zeros(2)
for it, th in enumerate(Theta):
  Error[it]=min[it]-Theta[it]
print(Error)
print(np.sqrt(Error[0]**2+Error[1]**2))
# Out:
# [0.9785210429789825, 0.922194618273722]
# [3.02147896 1.07780538]
# 3.2079587791302657

# %%
#50 IETRACIONES
from numpy.core.fromnumeric import resize
func = lambda th: (th[0]-4)**2+4*(th[1]-2)**2

#Representamos la funcion
_x =np.linspace(-16,16, 100)
_y =np.linspace(-16,16, 100)
_z=np.zeros((100,100))
for ix, x in enumerate(_x):
  for iy, y in enumerate(_y):
    _z[iy,ix]=func([x,y])

plt.contourf(_x,_y,_z,100)
plt.colorbar()

#Algoritmo AdaMax
Theta = [0,0]
lr=0.01
b1= 0.9
b2=0.999
k=1
E=10**(-8)
plt.plot(Theta[0],Theta[1], "o", c = "white")
grad=np.zeros(2)
m=[0,0]
v=[0,0]
M=np.zeros(2)
V=np.zeros(2)
iteraciones=50

for _ in range(iteraciones):

  grad[0] = 2*Theta[0]-8
  grad[1]= 8*Theta[1]-16

  for it, th in enumerate(Theta):
      m[it]= b1*m[it] + (1-b1)* grad[it]
      v[it]= b2*v[it] + (1-b2)* grad[it]**2
  
  b1k= b1**(k)
  b2k= b2**(k)
  k=k+1

  for it, th in enumerate(Theta):
    M[it]= m[it]/(1-b1k)
    V[it]= v[it]/(1-b2k)
  
  for it, th in enumerate(Theta):  

    Theta[it] = Theta[it] - (lr/ np.sqrt(V[it] + E)) * (b1*M[it] + (1-b1)*grad[it]/(1-b1k))
    #print(Theta)
    plt.plot(Theta[0],Theta[1], ".", c = "red")
print(Theta)
plt.plot(Theta[0],Theta[1], "o", c = "green")

plt.show()

min=[4,2]
Error=np.zeros(2)
for it, th in enumerate(Theta):
  Error[it]=min[it]-Theta[it]
print(Error)
print(np.sqrt(Error[0]**2+Error[1]**2))
# Out:
# [0.5178285543005968, 0.5076231143104075]
# [3.48217145 1.49237689]
# 3.7884966340469197

# %%
#10 IETRACIONES
from numpy.core.fromnumeric import resize
func = lambda th: (th[0]-4)**2+4*(th[1]-2)**2

#Representamos la funcion
_x =np.linspace(-16,16, 100)
_y =np.linspace(-16,16, 100)
_z=np.zeros((100,100))
for ix, x in enumerate(_x):
  for iy, y in enumerate(_y):
    _z[iy,ix]=func([x,y])

plt.contourf(_x,_y,_z,100)
plt.colorbar()

#Algoritmo AdaMax
Theta = [0,0]
lr=0.01
b1= 0.9
b2=0.999
k=1
E=10**(-8)
plt.plot(Theta[0],Theta[1], "o", c = "white")
grad=np.zeros(2)
m=[0,0]
v=[0,0]
M=np.zeros(2)
V=np.zeros(2)
iteraciones=10

for _ in range(iteraciones):

  grad[0] = 2*Theta[0]-8
  grad[1]= 8*Theta[1]-16

  for it, th in enumerate(Theta):
      m[it]= b1*m[it] + (1-b1)* grad[it]
      v[it]= b2*v[it] + (1-b2)* grad[it]**2
  
  b1k= b1**(k)
  b2k= b2**(k)
  k=k+1

  for it, th in enumerate(Theta):
    M[it]= m[it]/(1-b1k)
    V[it]= v[it]/(1-b2k)
  
  for it, th in enumerate(Theta):  

    Theta[it] = Theta[it] - (lr/ np.sqrt(V[it] + E)) * (b1*M[it] + (1-b1)*grad[it]/(1-b1k))
    #print(Theta)
    plt.plot(Theta[0],Theta[1], ".", c = "red")
print(Theta)
plt.plot(Theta[0],Theta[1], "o", c = "green")

plt.show()

min=[4,2]
Error=np.zeros(2)
for it, th in enumerate(Theta):
  Error[it]=min[it]-Theta[it]
print(Error)
print(np.sqrt(Error[0]**2+Error[1]**2))
# Out:
# [0.1230299153520108, 0.12277386261238671]
# [3.87697008 1.87722614]
# 4.3075370002063424
